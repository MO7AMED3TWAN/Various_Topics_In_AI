# %% [markdown]
# # Data in Pandas

# %% [markdown]
# ## IRIS DATA

# %%
from sklearn.datasets import load_iris
IrisData = load_iris()

##features
X = IrisData.data #here we take the columns of featuers'independent values'
Feature_Names=IrisData.feature_names
print("X shape is {}".format(X.shape))
print("Feature Names is : {}\n".format(Feature_Names))

##Target
y=IrisData.target #here we take the columns of target 'dependent values'
Targe_Names=IrisData.target_names
print(f"y shape is {y.shape}")
print(f"Target Names is : {Targe_Names}")
# Out:
# X shape is (150, 4)
# Feature Names is : ['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)', 'petal width (cm)']
#
# y shape is (150,)
# Target Names is : ['setosa' 'versicolor' 'virginica']

# %% [markdown]
# ## DIGITS DATA

# %%
from sklearn.datasets import load_digits
DigitsData = load_digits()

##features
X = DigitsData.data #here we take the columns of featuers'independent values'
print("X shape is {}".format(X.shape))

##Target
y = DigitsData.target #here we take the columns of target 'dependent values'
print(f"y shape is {y.shape}")
# Out:
# X shape is (1797, 64)
# y shape is (1797,)

# %% [markdown]
# ## CALIFORNIA DATA

# %%
from sklearn.datasets import fetch_california_housing
housing = fetch_california_housing()

##features
X = housing.data #here we take the columns of featuers'independent values'
Feature_Names=housing.feature_names
print("X shape is {}".format(X.shape))
print("Feature Names is : {}\n".format(Feature_Names))

##Target
y = housing.target #here we take the columns of target 'dependent values'
Targe_Names=housing.target_names
print(f"y shape is {y.shape}")
print(f"Target Names is : {Targe_Names}")
# Out:
# X shape is (20640, 8)
# Feature Names is : ['MedInc', 'HouseAge', 'AveRooms', 'AveBedrms', 'Population', 'AveOccup', 'Latitude', 'Longitude']
#
# y shape is (20640,)
# Target Names is : ['MedHouseVal']

# %% [markdown]
# ## WINE DATA

# %%
from sklearn.datasets import load_wine
WineData = load_wine()

##features
X = WineData.data #here we take the columns of featuers'independent values'
Feature_Names=WineData.feature_names
print("X shape is {}".format(X.shape))
print("Feature Names is : {}\n".format(Feature_Names))

##Target
y = WineData.target #here we take the columns of target 'dependent values'
Targe_Names=WineData.target_names
print(f"y shape is {y.shape}")
print(f"Target Names is : {Targe_Names}")
# Out:
# X shape is (178, 13)
# Feature Names is : ['alcohol', 'malic_acid', 'ash', 'alcalinity_of_ash', 'magnesium', 'total_phenols', 'flavanoids', 'nonflavanoid_phenols', 'proanthocyanins', 'color_intensity', 'hue', 'od280/od315_of_diluted_wines', 'proline']
#
# y shape is (178,)
# Target Names is : ['class_0' 'class_1' 'class_2']

# %% [markdown]
# ## BREAST CANCER DATA

# %%
from sklearn.datasets import load_breast_cancer
BreastData = load_breast_cancer()

##features
X = BreastData.data #here we take the columns of featuers'independent values'
Feature_Names=BreastData.feature_names
print("X shape is {}".format(X.shape))
print("Feature Names is : {}\n".format(Feature_Names))

##Target
y = BreastData.target #here we take the columns of target 'dependent values'
Targe_Names=BreastData.target_names
print(f"y shape is {y.shape}")
print(f"Target Names is : {Targe_Names}")
# Out:
# X shape is (569, 30)
# Feature Names is : ['mean radius' 'mean texture' 'mean perimeter' 'mean area'
#  'mean smoothness' 'mean compactness' 'mean concavity'
#  'mean concave points' 'mean symmetry' 'mean fractal dimension'
#  'radius error' 'texture error' 'perimeter error' 'area error'
#  'smoothness error' 'compactness error' 'concavity error'
#  'concave points error' 'symmetry error' 'fractal dimension error'
#  'worst radius' 'worst texture' 'worst perimeter' 'worst area'
#  'worst smoothness' 'worst compactness' 'worst concavity'
#  'worst concave points' 'worst symmetry' 'worst fractal dimension']
#
# y shape is (569,)
# Target Names is : ['malignant' 'benign']

# %% [markdown]
# ## DIABETES DATA

# %%
from sklearn.datasets import load_diabetes
DiabetesData= load_diabetes()

##features
X = DiabetesData.data #here we take the columns of featuers'independent values'
Feature_Names=DiabetesData.feature_names
print("X shape is {}".format(X.shape))
print("Feature Names is : {}\n".format(Feature_Names))

##Target
y = DiabetesData.target #here we take the columns of target 'dependent values'
# Targe_Names=DiabetesData.target_names #NO NAMES FOR THIS DATA
print(f"y shape is {y.shape}")
# print(f"Target Names is : {Targe_Names}") #NO NAMES FOR THIS DATA
# Out:
# X shape is (442, 10)
# Feature Names is : ['age', 'sex', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6']
#
# y shape is (442,)

# %% [markdown]
# ## SAMPLE IMAGES DATA

# %%
from sklearn.datasets import load_sample_image

china = load_sample_image('china.jpg')
china.dtype
china.shape


flower = load_sample_image('flower.jpg')
flower.dtype
flower.shape

import matplotlib.pyplot as plt
plt.imshow(china)
plt.imshow(flower)

# %% [markdown]
# ## REGRESSION DATA

# %%
from sklearn.datasets import make_regression
#load regression data
'''
X ,y = make_regression(n_samples=100, n_features=100, n_informative=10,
                       n_targets=1, bias=0.0, effective_rank=None,
                       tail_strength=0.5, noise=0.0, shuffle=True, coef=False,
                       random_state=None)
'''

X ,y = make_regression(n_samples=1000, n_features=10,shuffle=True)

##features
# print('X Data is \n' , X[:10])
print('X shape is ' , X.shape)

##Target
# print('y Data is \n' , y[:10])
print('y shape is ' , y.shape)
# Out:
# X shape is  (1000, 10)
# y shape is  (1000,)

# %% [markdown]
# ## CLASSIFiCATION DATA

# %%
#Import Libraries
from sklearn.datasets import make_classification
#----------------------------------------------------

#load classification data

'''
X, y = make_classification(n_samples = 100, n_features = 20, n_informative = 2, n_redundant = 2,
                           n_repeated = 0, n_classes = 2, n_clusters_per_class = 2, weights = None,
                           flip_y = 0.01, class_sep = 1.0, hypercube = True, shift = 0.0,
                           Scale() = 1.0, shuffle = True, random_state = None)
'''

X, y = make_classification(n_samples = 100, n_classes = 2, n_features = 20, shuffle = True)

##features
# print('X Data is \n' , X[:10])
print('X shape is ' , X.shape)

##Target
# print('y Data is \n' , y[:10])
print('y shape is ' , y.shape)
# Out:
# X shape is  (100, 20)
# y shape is  (100,)

# %% [markdown]
# ## EXPORTING DATA

# %% [markdown]
# # TO EXCEl

# %%
#here data that i want export it
import pandas as pd

from sklearn.datasets import fetch_california_housing
housing = fetch_california_housing()

##features
X = housing.data #here we take the columns of featuers'independent values'
Feature_Names=housing.feature_names
print("X shape is {}".format(X.shape))
print("Feature Names is : {}\n".format(Feature_Names))
##Target
y = housing.target #here we take the columns of target 'dependent values'
Targe_Names=housing.target_names
print(f"y shape is {y.shape}")
print(f"Target Names is : {Targe_Names}")

# data = pd.DataFrame(X,y)

# out=data.to_csv("out.csv")
# Out:
# X shape is (20640, 8)
# Feature Names is : ['MedInc', 'HouseAge', 'AveRooms', 'AveBedrms', 'Population', 'AveOccup', 'Latitude', 'Longitude']
#
# y shape is (20640,)
# Target Names is : ['MedHouseVal']

# %% [markdown]
# # TO TXT
